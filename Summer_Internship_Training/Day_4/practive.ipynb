# %%
name = "Alice"
age = 18
height = 5.6
in_student = True

print(name, age, height, in_student)
# Out:
# Alice 18 5.6 True

# %%
# type conversion

x = "100"
y = int(x)  
z = float(x)
s = str(y)

print("x", x, "type:", type(x))
print("y", y, "type:", type(y))
print("z", z, "type:", type(z))
print("s", s, "type:", type(s))
# Out:
# x 100 type: <class 'str'>
# y 100 type: <class 'int'>
# z 100.0 type: <class 'float'>
# s 100 type: <class 'str'>
