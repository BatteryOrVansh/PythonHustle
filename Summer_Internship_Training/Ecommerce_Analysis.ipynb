# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data.csv", encoding="latin1")

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/2011 12:50       0.85     12680.0  France
# 541905  12/9/2011 12:50       2.10     12680.0  France
# 541906  12/9/2011 12:50       4.15     12680.0  France
# 541907  12/9/2011 12:50       4.15     12680.0  France
# 541908  12/9/2011 12:50       4.95     12680.0  France

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85     12680.0          France
# 541905  12/9/2011 12:50       2.10     12680.0          France
# 541906  12/9/2011 12:50       4.15     12680.0          France
# 541907  12/9/2011 12:50       4.15     12680.0          France
# 541908  12/9/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
print("Basic Description\n", df.describe())
# Out:
# Basic Description
#              Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df.describe(include="all")
# Out:
#        InvoiceNo StockCode                         Description       Quantity  \
# count     541909    541909                              540455  541909.000000
# unique     25900      4070                                4223            NaN
# top       573585    85123A  WHITE HANGING HEART T-LIGHT HOLDER            NaN
# freq        1114      2313                                2369            NaN
# mean         NaN       NaN                                 NaN       9.552250
# std          NaN       NaN                                 NaN     218.081158
# min          NaN       NaN                                 NaN  -80995.000000
# 25%          NaN       NaN                                 NaN       1.000000
# 50%          NaN       NaN                                 NaN       3.000000
# 75%          NaN       NaN                                 NaN      10.000000
# max          NaN       NaN                                 NaN   80995.000000
#
#              InvoiceDate      UnitPrice     CustomerID         Country
# count             541909  541909.000000  406829.000000          541909
# unique             23260            NaN            NaN              38
# top     10/31/2011 14:41            NaN            NaN  United Kingdom
# freq                1114            NaN            NaN          495478
# mean                 NaN       4.611114   15287.690570             NaN
# std                  NaN      96.759853    1713.600303             NaN
# min                  NaN  -11062.060000   12346.000000             NaN
# 25%                  NaN       1.250000   13953.000000             NaN
# 50%                  NaN       2.080000   15152.000000             NaN
# 75%                  NaN       4.130000   16791.000000             NaN
# max                  NaN   38970.000000   18287.000000             NaN

# %%
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %% [markdown]
# # **DATA CLEANING** ✅

# %%
print("Check Missing Values:\n", df.isnull())
# Out:
# Check Missing Values:
#          InvoiceNo  StockCode  Description  Quantity  InvoiceDate  UnitPrice  \
# 0           False      False        False     False        False      False
# 1           False      False        False     False        False      False
# 2           False      False        False     False        False      False
# 3           False      False        False     False        False      False
# 4           False      False        False     False        False      False
# ...           ...        ...          ...       ...          ...        ...
# 541904      False      False        False     False        False      False
# 541905      False      False        False     False        False      False
# 541906      False      False        False     False        False      False
# 541907      False      False        False     False        False      False
# 541908      False      False        False     False        False      False
#
#         CustomerID  Country
# 0            False    False
# 1            False    False
# 2            False    False
# 3            False    False
# 4            False    False
# ...            ...      ...
# 541904       False    False
# 541905       False    False
# 541906       False    False
# 541907       False    False
# 541908       False    False
#
# [541909 rows x 8 columns]

# %%
print("Total missing values:\n", df.isnull().sum())
# Out:
# Total missing values:
#  InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df = df.dropna(subset=["Description"])
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description         0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     133626
# Country             0
# dtype: int64

# %%
df_with_customer = df.dropna(subset=["CustomerID"]).copy()
df_with_customer["CustomerID"] = df_with_customer["CustomerID"].astype(int)

df_with_customer
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55       17850  United Kingdom
# 1        12/1/2010 8:26       3.39       17850  United Kingdom
# 2        12/1/2010 8:26       2.75       17850  United Kingdom
# 3        12/1/2010 8:26       3.39       17850  United Kingdom
# 4        12/1/2010 8:26       3.39       17850  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85       12680          France
# 541905  12/9/2011 12:50       2.10       12680          France
# 541906  12/9/2011 12:50       4.15       12680          France
# 541907  12/9/2011 12:50       4.15       12680          France
# 541908  12/9/2011 12:50       4.95       12680          France
#
# [406829 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description         0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     133626
# Country             0
# dtype: int64

# %%
df_with_customer.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
df["IsCancelled"] = df["InvoiceNo"].astype(str).str.startswith("C")
df["IsCancelled"]
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 541904    False
# 541905    False
# 541906    False
# 541907    False
# 541908    False
# Name: IsCancelled, Length: 540455, dtype: bool

# %%
# Create a new dataframe only keepig valid transaction
df_clean = df[
    (~df["IsCancelled"]) & # keep only rows where IsCancelled is false, means confirm orders
    (df["Quantity"] > 0) & # keep only those rows where quamtity is greater than 0
    (df["UnitPrice"] > 0) # keep those rows where price is greater than 0
].copy() # create a seperate copy of the filtered dataframe

# %%
df_clean
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  IsCancelled
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom        False
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom        False
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom        False
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom        False
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom        False
# ...                 ...        ...         ...             ...          ...
# 541904  12/9/2011 12:50       0.85     12680.0          France        False
# 541905  12/9/2011 12:50       2.10     12680.0          France        False
# 541906  12/9/2011 12:50       4.15     12680.0          France        False
# 541907  12/9/2011 12:50       4.15     12680.0          France        False
# 541908  12/9/2011 12:50       4.95     12680.0          France        False
#
# [530104 rows x 9 columns]

# %%
# pd.to_datetime is used to convert into standardized pandas datetime objects

df_clean["InvoiceDate"] = pd.to_datetime(df_clean["InvoiceDate"])
df["InvoiceDate"]
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: InvoiceDate, Length: 540455, dtype: datetime64[ns]

# %%
# Create a new column "Total Price" to calculate the total amnt for each txn
# Total Price = qty * unitPrice
# we use np.multiply() to perform element wise multiplication between the two col

df_clean["TotalPrice"] = np.multiply(df_clean["Quantity"], df_clean["UnitPrice"])
df_clean["TotalPrice"]
# Out:
# 0         15.30
# 1         20.34
# 2         22.00
# 3         20.34
# 4         20.34
#           ...
# 541904    10.20
# 541905    12.60
# 541906    16.60
# 541907    16.60
# 541908    14.85
# Name: TotalPrice, Length: 530104, dtype: float64

# %%
print("STEP3: Data Cleaned")
print("Original Rows: ", df.shape[0], "| Clean rows: ", df_clean.shape[0])
print("Cancelled orders removed: ", df["IsCancelled"].sum())
print(df_clean[["InvoiceNo", "Quantity", "UnitPrice", "TotalPrice", "InvoiceDate"]])
print("\n")
# Out:
# STEP3: Data Cleaned
# Original Rows:  540455 | Clean rows:  530104
# Cancelled orders removed:  9288
#        InvoiceNo  Quantity  UnitPrice  TotalPrice         InvoiceDate
# 0         536365         6       2.55       15.30 2010-12-01 08:26:00
# 1         536365         6       3.39       20.34 2010-12-01 08:26:00
# 2         536365         8       2.75       22.00 2010-12-01 08:26:00
# 3         536365         6       3.39       20.34 2010-12-01 08:26:00
# 4         536365         6       3.39       20.34 2010-12-01 08:26:00
# ...          ...       ...        ...         ...                 ...
# 541904    581587        12       0.85       10.20 2011-12-09 12:50:00
# 541905    581587         6       2.10       12.60 2011-12-09 12:50:00
# 541906    581587         4       4.15       16.60 2011-12-09 12:50:00
# 541907    581587         4       4.15       16.60 2011-12-09 12:50:00
# 541908    581587         3       4.95       14.85 2011-12-09 12:50:00
#
# [530104 rows x 5 columns]

# %% [markdown]
# # STEP 4: Date-based feature (for time analysis)

# %%
# Extract the year from the "InvoiceDate" column and store it in a new column "Year"
df_clean["Year"] = df_clean["InvoiceDate"].dt.year

#Extract the month (1-12 from the "InvoiceDate" col
df_clean["Month"] = df_clean["InvoiceDate"].dt.month

# Extract the day of the month (1-31) from the "InvoiceDate" column
df_clean["Day"] = df_clean["InvoiceDate"].dt.day

# Extract the day of the week (0-6) from the "InvoiceDate" column
df_clean["DayOfWeek"] = df_clean["InvoiceDate"].dt.dayofweek

#Extract the hour (0-23) from the "InvoiceDate"
df_clean["Hour"] = df_clean["InvoiceDate"].dt.hour

# Extract the minute (0-59) from the "InvoiceDate" column
df_clean["Minute"] = df_clean["InvoiceDate"].dt.minute

# %%
df_clean
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
#         IsCancelled  TotalPrice  Year  Month  Day  DayOfWeek  Hour  Minute
# 0             False       15.30  2010     12    1          2     8      26
# 1             False       20.34  2010     12    1          2     8      26
# 2             False       22.00  2010     12    1          2     8      26
# 3             False       20.34  2010     12    1          2     8      26
# 4             False       20.34  2010     12    1          2     8      26
# ...             ...         ...   ...    ...  ...        ...   ...     ...
# 541904        False       10.20  2011     12    9          4    12      50
# 541905        False       12.60  2011     12    9          4    12      50
# 541906        False       16.60  2011     12    9          4    12      50
# 541907        False       16.60  2011     12    9          4    12      50
# 541908        False       14.85  2011     12    9          4    12      50
#
# [530104 rows x 16 columns]
