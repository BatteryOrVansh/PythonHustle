# %% [markdown]
# ## SCATTER PLOT

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[3,5,7,2,8]
plt.scatter(x,y)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('scatter plot')
plt.show()
