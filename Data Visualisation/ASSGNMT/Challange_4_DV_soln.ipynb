# %% [markdown]
# ## VANSH DIXIT
# ## BTECH CSE IOTBC
# ## CHALLENGE 4 COMPLETED
# ## ROLL : 1230440060

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Certainly, here are the previous questions adapted for creating bar plots in Colab:
#
# **Question 1: Movie Genre Frequency**
#
# **Data:**
#
# The CSV file contains information about movies:
#
# * **Title:** Movie title (string) - **Do not use for plotting**
# * **Genre:** Movie genre (string)
#
# **Task:** Create a bar plot to show the **frequency of movies** belonging to each genre.
#
# **Data Example (movies.csv):**
#
# ```csv
# Title,Genre
# The Shawshank Redemption,Drama
# The Godfather,Crime
# The Dark Knight,Action,Thriller
# The Godfather: Part II,Crime
# Pulp Fiction,Crime,Comedy
# The Lord of the Rings: The Return of the King,Fantasy,Adventure
# Schindler's List,Historical Drama
# 12 Angry Men,Drama
# The Lord of the Rings: The Fellowship of the Ring,Fantasy,Adventure
# Fight Club,Drama
# ```
#
# **Colab Code:**

# %%
data={'Title':['The Shawshank Redemption', 'The Godfather','The Dark Knight','The Godfather: Part II','Pulp Fiction','TLOTR 2',
               'Schindler\'s List','12 Angry Men','TLOTR 1','Fight Club'],
               'Genre':['Drama','Crime','Action','Crime','Crime','Fantasy','Historical Drama','Drama','Fantasy','Drama']}
df=pd.DataFrame(data)
df
# Out:
#                       Title             Genre
# 0  The Shawshank Redemption             Drama
# 1             The Godfather             Crime
# 2           The Dark Knight            Action
# 3    The Godfather: Part II             Crime
# 4              Pulp Fiction             Crime
# 5                   TLOTR 2           Fantasy
# 6          Schindler's List  Historical Drama
# 7              12 Angry Men             Drama
# 8                   TLOTR 1           Fantasy
# 9                Fight Club             Drama

# %%
mc=df['Genre'].value_counts().plot(kind='bar',color='magenta',edgecolor='black')
plt.ylabel('Frequency')
plt.title('Frequency of Genre of Movies')
# Out:
# Text(0.5, 1.0, 'Frequency of Genre of Movies')

# %% [markdown]
# **Explanation:**
#
# * This code uses `pandas.value_counts` to count the occurrences of each genre.
# * The `plot(kind='bar')` function creates the bar plot.
#
# **Question 2: Plant Growth Stages**
#
# **Data:**
#
# Imagine you have data on plant growth stages:
#
# * **Plant Name:** Name of the plant (string) - **Do not use for plotting**
# * **Growth Stage:** Current growth stage of the plant (string)
#
# **Task:** Create a bar plot to visualize the **distribution of plants** across different growth stages.
#
# **Data Example:** (This data can be hypothetical and doesn't require a CSV file)
#
# | Plant Name | Growth Stage |
# |---|---|
# | Plant A | Seedling |
# | Plant B | Sprout |
# | Plant C | Vegetative |
# | Plant D | Flowering |
# | Plant E | Fruiting |
#
# **Colab Code:**

# %%
# creating custom data because bar plot can't be made without one axis with numerical value     
data={'Plant_Name':['Rose','Lotus','Neem','Sunflower','Tulsi'],
      'Quantity':[10,12,4,5,8]}
df=pd.DataFrame(data)
plt.bar(df['Plant_Name'],df['Quantity'],color='pink',edgecolor='black')
plt.xlabel('Plant Name')
plt.ylabel('Quantity')
plt.title('Quantity of Plants')
plt.show()

# %% [markdown]
# **Question 3: Online Store - Purchase Frequency by Age Group**
#
# **Data:**
#
# A CSV file contains customer purchase information for an online store:
#
# * **Customer ID:** Unique identifier (string) - **Do not use for plotting**
# * **Customer Age:** Age of the customer (integer)
#
# **Task:** Create a bar plot to show the **frequency of purchases** made by customers within different age groups.
#
# **Data Example (online_store.csv):**
#
# ```csv
# Customer ID,Customer Age
# 1001,25
# 1002,32
# 1003,48
# 1004,19
# 1005,65
# 1006,28
# 1007,52
# 1008,35
# 1009,18
# 1010,70
# ```
#
# **Colab Code:**

# %%
#altering the ages for better visualization in the bar plot.. other way could be to create age groups but that would be a bit advanced
data={'CID':[101,102,103,104,105,106,107],
      'Age':[10,12,17,10,15,14,11]}
df=pd.DataFrame(data)
plt.bar(df['CID'],df['Age'],color='red',edgecolor='black')
plt.xlabel('Customer ID')
plt.ylabel('Age')
plt.title('Customer\'s Age')
plt.show()
